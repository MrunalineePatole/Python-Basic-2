# %%
import pandas as pd

# %%
pr=pd.read_csv('E:/datasets/Property_Price_Train.csv')

# %%
pr.head()
# Out:
#    Id  Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Lane_Type  \
# 0   1              60          RLD        65.0      8450     Paved       NaN
# 1   2              20          RLD        80.0      9600     Paved       NaN
# 2   3              60          RLD        68.0     11250     Paved       NaN
# 3   4              70          RLD        60.0      9550     Paved       NaN
# 4   5              60          RLD        84.0     14260     Paved       NaN
#
#   Property_Shape Land_Outline Utility_Type  ... Pool_Area Pool_Quality  \
# 0            Reg          Lvl       AllPub  ...         0          NaN
# 1            Reg          Lvl       AllPub  ...         0          NaN
# 2            IR1          Lvl       AllPub  ...         0          NaN
# 3            IR1          Lvl       AllPub  ...         0          NaN
# 4            IR1          Lvl       AllPub  ...         0          NaN
#
#   Fence_Quality Miscellaneous_Feature Miscellaneous_Value Month_Sold  \
# ...

# %%
pr.columns
# Out:
# Index(['Id', 'Building_Class', 'Zoning_Class', 'Lot_Extent', 'Lot_Size',
#        'Road_Type', 'Lane_Type', 'Property_Shape', 'Land_Outline',
#        'Utility_Type', 'Lot_Configuration', 'Property_Slope', 'Neighborhood',
#        'Condition1', 'Condition2', 'House_Type', 'House_Design',
#        'Overall_Material', 'House_Condition', 'Construction_Year',
#        'Remodel_Year', 'Roof_Design', 'Roof_Quality', 'Exterior1st',
#        'Exterior2nd', 'Brick_Veneer_Type', 'Brick_Veneer_Area',
#        'Exterior_Material', 'Exterior_Condition', 'Foundation_Type',
#        'Basement_Height', 'Basement_Condition', 'Exposure_Level',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'Total_Basement_Area', 'Heating_Type', 'Heating_Quality',
#        'Air_Conditioning', 'Electrical_System', 'First_Floor_Area',
#        'Second_Floor_Area', 'LowQualFinSF', 'Grade_Living_Area',
#        'Underground_Full_Bathroom', 'Underground_Half_Bathroom',
# ...

# %%
pr.columns[pr.isnull().sum()*100/pr.shape[0]>50]
# Out:
# Index(['Lane_Type', 'Pool_Quality', 'Fence_Quality', 'Miscellaneous_Feature'], dtype='object')

# %%
pr=pr.loc[:,['Building_Class', 'Zoning_Class', 'Lot_Extent', 'Lot_Size',
       'Road_Type', 'Property_Shape', 'Land_Outline',
       'Utility_Type', 'Lot_Configuration', 'Property_Slope', 'Neighborhood',
       'Condition1', 'Condition2', 'House_Type', 'House_Design',
       'Overall_Material', 'House_Condition', 'Construction_Year',
       'Remodel_Year', 'Roof_Design', 'Roof_Quality', 'Exterior1st',
       'Exterior2nd', 'Brick_Veneer_Type', 'Brick_Veneer_Area',
       'Exterior_Material', 'Exterior_Condition', 'Foundation_Type',
       'Basement_Height', 'Basement_Condition', 'Exposure_Level',
       'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
       'Total_Basement_Area', 'Heating_Type', 'Heating_Quality',
       'Air_Conditioning', 'Electrical_System', 'First_Floor_Area',
       'Second_Floor_Area', 'LowQualFinSF', 'Grade_Living_Area',
       'Underground_Full_Bathroom', 'Underground_Half_Bathroom',
       'Full_Bathroom_Above_Grade', 'Half_Bathroom_Above_Grade',
       'Bedroom_Above_Grade', 'Kitchen_Above_Grade', 'Kitchen_Quality',
       'Rooms_Above_Grade', 'Functional_Rate', 'Fireplaces',
       'Fireplace_Quality', 'Garage', 'Garage_Built_Year',
       'Garage_Finish_Year', 'Garage_Size', 'Garage_Area', 'Garage_Quality',
       'Garage_Condition', 'Pavedd_Drive', 'W_Deck_Area', 'Open_Lobby_Area',
       'Enclosed_Lobby_Area', 'Three_Season_Lobby_Area', 'Screen_Lobby_Area',
       'Pool_Area',
       'Miscellaneous_Value', 'Month_Sold', 'Year_Sold', 'Sale_Type',
       'Sale_Condition', 'Sale_Price']]

# %%
pr.head()
# Out:
#    Building_Class Zoning_Class  Lot_Extent  Lot_Size Road_Type Property_Shape  \
# 0              60          RLD        65.0      8450     Paved            Reg
# 1              20          RLD        80.0      9600     Paved            Reg
# 2              60          RLD        68.0     11250     Paved            IR1
# 3              70          RLD        60.0      9550     Paved            IR1
# 4              60          RLD        84.0     14260     Paved            IR1
#
#   Land_Outline Utility_Type Lot_Configuration Property_Slope  ...  \
# 0          Lvl       AllPub                 I             GS  ...
# 1          Lvl       AllPub              FR2P             GS  ...
# 2          Lvl       AllPub                 I             GS  ...
# 3          Lvl       AllPub                 C             GS  ...
# 4          Lvl       AllPub              FR2P             GS  ...
#
#   Enclosed_Lobby_Area Three_Season_Lobby_Area Screen_Lobby_Area Pool_Area  \
# ...

# %%
pr.isnull().sum()
# Out:
# Building_Class      0
# Zoning_Class        0
# Lot_Extent        259
# Lot_Size            0
# Road_Type           0
#                  ...
# Month_Sold          0
# Year_Sold           0
# Sale_Type           0
# Sale_Condition      0
# Sale_Price          0
# Length: 76, dtype: int64

# %%
pr.describe(include='all')
# Out:
#         Building_Class Zoning_Class   Lot_Extent       Lot_Size Road_Type  \
# count      1459.000000         1459  1200.000000    1459.000000      1459
# unique             NaN            5          NaN            NaN         2
# top                NaN          RLD          NaN            NaN     Paved
# freq               NaN         1150          NaN            NaN      1453
# mean         56.922550          NaN    70.045833   10517.225497       NaN
# std          42.304033          NaN    24.294456    9984.675721       NaN
# min          20.000000          NaN    21.000000    1300.000000       NaN
# 25%          20.000000          NaN    59.000000    7549.000000       NaN
# 50%          50.000000          NaN    69.000000    9477.000000       NaN
# 75%          70.000000          NaN    80.000000   11603.000000       NaN
# max         190.000000          NaN   313.000000  215245.000000       NaN
#
#        Property_Shape Land_Outline Utility_Type Lot_Configuration  \
# ...

# %%
pr.Lot_Extent=pr.Lot_Extent.fillna(pr.Lot_Extent.median())
pr.Brick_Veneer_Type=pr.Brick_Veneer_Type.fillna('None')
pr.Exposure_Level=pr.Exposure_Level.fillna('No')
pr.BsmtFinType1=pr.BsmtFinType1.fillna('Unf')
pr.BsmtFinType2=pr.BsmtFinType2.fillna('Unf')
pr.Electrical_System=pr.Electrical_System.fillna('SBrkr')
pr.Garage_Built_Year=pr.Garage_Built_Year.fillna('2005')
pr.Fireplace_Quality=pr.Fireplace_Quality.fillna('Gd')
pr.Garage=pr.Garage.fillna('Attchd')
pr.Garage_Finish_Year=pr.Garage_Finish_Year.fillna('Unf')
pr.Garage_Quality=pr.Garage_Quality.fillna('TA')
pr.Garage_Condition=pr.Garage_Condition.fillna('TA')
pr.Basement_Height=pr.Basement_Height.fillna('TA')
pr.Basement_Condition=pr.Basement_Condition.fillna('TA')
pr.Brick_Veneer_Area=pr.Brick_Veneer_Area.fillna(pr.Brick_Veneer_Area.mean())


pr.isnull().sum()
# Out:
# Building_Class               0
# Zoning_Class                 0
# Lot_Extent                   0
# Lot_Size                     0
# Road_Type                    0
# Property_Shape               0
# Land_Outline                 0
# Utility_Type                 0
# Lot_Configuration            0
# Property_Slope               0
# Neighborhood                 0
# Condition1                   0
# Condition2                   0
# House_Type                   0
# House_Design                 0
# Overall_Material             0
# House_Condition              0
# Construction_Year            0
# Remodel_Year                 0
# Roof_Design                  0
# Roof_Quality                 0
# Exterior1st                  0
# Exterior2nd                  0
# Brick_Veneer_Type            0
# Brick_Veneer_Area            0
# Exterior_Material            0
# Exterior_Condition           0
# Foundation_Type              0
# Basement_Height              0
# Basement_Condition           0
# ...

# %%
pr.describe(include='all')
# Out:
#         Building_Class Zoning_Class   Lot_Extent       Lot_Size Road_Type  \
# count      1459.000000         1459  1459.000000    1459.000000      1459
# unique             NaN            5          NaN            NaN         2
# top                NaN          RLD          NaN            NaN     Paved
# freq               NaN         1150          NaN            NaN      1453
# mean         56.922550          NaN    69.860178   10517.225497       NaN
# std          42.304033          NaN    22.034819    9984.675721       NaN
# min          20.000000          NaN    21.000000    1300.000000       NaN
# 25%          20.000000          NaN    60.000000    7549.000000       NaN
# 50%          50.000000          NaN    69.000000    9477.000000       NaN
# 75%          70.000000          NaN    79.000000   11603.000000       NaN
# max         190.000000          NaN   313.000000  215245.000000       NaN
#
#        Property_Shape Land_Outline Utility_Type Lot_Configuration  \
# ...

# %%
import sklearn
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
pr.select_dtypes(include='object').columns
# Out:
# Index(['Zoning_Class', 'Road_Type', 'Property_Shape', 'Land_Outline',
#        'Utility_Type', 'Lot_Configuration', 'Property_Slope', 'Neighborhood',
#        'Condition1', 'Condition2', 'House_Type', 'House_Design', 'Roof_Design',
#        'Roof_Quality', 'Exterior1st', 'Exterior2nd', 'Brick_Veneer_Type',
#        'Exterior_Material', 'Exterior_Condition', 'Foundation_Type',
#        'Basement_Height', 'Basement_Condition', 'Exposure_Level',
#        'BsmtFinType1', 'BsmtFinType2', 'Heating_Type', 'Heating_Quality',
#        'Air_Conditioning', 'Electrical_System', 'Kitchen_Quality',
#        'Functional_Rate', 'Fireplace_Quality', 'Garage', 'Garage_Built_Year',
#        'Garage_Finish_Year', 'Garage_Quality', 'Garage_Condition',
#        'Pavedd_Drive', 'Sale_Type', 'Sale_Condition'],
#       dtype='object')

# %%
pd.set_option( "display.max_rows" , None)
pr.info()
pr.Brick_Veneer_Area.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 76 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Building_Class             1459 non-null   int64
#  1   Zoning_Class               1459 non-null   object
#  2   Lot_Extent                 1459 non-null   float64
#  3   Lot_Size                   1459 non-null   int64
#  4   Road_Type                  1459 non-null   object
#  5   Property_Shape             1459 non-null   object
#  6   Land_Outline               1459 non-null   object
#  7   Utility_Type               1459 non-null   object
#  8   Lot_Configuration          1459 non-null   object
#  9   Property_Slope             1459 non-null   object
#  10  Neighborhood               1459 non-null   object
#  11  Condition1                 1459 non-null   object
#  12  Condition2                 1459 non-null   object
# ...

# %%
pr.isnull().sum()
# Out:
# Building_Class               0
# Zoning_Class                 0
# Lot_Extent                   0
# Lot_Size                     0
# Road_Type                    0
# Property_Shape               0
# Land_Outline                 0
# Utility_Type                 0
# Lot_Configuration            0
# Property_Slope               0
# Neighborhood                 0
# Condition1                   0
# Condition2                   0
# House_Type                   0
# House_Design                 0
# Overall_Material             0
# House_Condition              0
# Construction_Year            0
# Remodel_Year                 0
# Roof_Design                  0
# Roof_Quality                 0
# Exterior1st                  0
# Exterior2nd                  0
# Brick_Veneer_Type            0
# Brick_Veneer_Area            0
# Exterior_Material            0
# Exterior_Condition           0
# Foundation_Type              0
# Basement_Height              0
# Basement_Condition           0
# ...

# %%
pr[pr.select_dtypes(include=['object']).columns]=pr[pr.select_dtypes(include=['object']).columns].apply(le.fit_transform)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-42ddc61abe5b> in <module>
# ----> 1 pr[pr.select_dtypes(include=['object']).columns]=pr[pr.select_dtypes(include=['object']).columns].apply(le.fit_transform())
#
# TypeError: fit_transform() missing 1 required positional argument: 'y'

# %%
pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 76 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Building_Class             1459 non-null   int64
#  1   Zoning_Class               1459 non-null   object
#  2   Lot_Extent                 1459 non-null   float64
#  3   Lot_Size                   1459 non-null   int64
#  4   Road_Type                  1459 non-null   object
#  5   Property_Shape             1459 non-null   object
#  6   Land_Outline               1459 non-null   object
#  7   Utility_Type               1459 non-null   object
#  8   Lot_Configuration          1459 non-null   object
#  9   Property_Slope             1459 non-null   object
#  10  Neighborhood               1459 non-null   object
#  11  Condition1                 1459 non-null   object
#  12  Condition2                 1459 non-null   object
# ...

# %%
#pr.Zoning_Class=le.fit_transform(pr.Zoning_Class)

pr.Road_Type=le.fit_transform(pr.Road_Type)
pr.Property_Shape=le.fit_transform(pr.Property_Shape)
pr.Land_Outline=le.fit_transform(pr.Land_Outline)
pr.Utility_Type=le.fit_transform(pr.Utility_Type)
pr.Lot_Configuration=le.fit_transform(pr.Lot_Configuration)
pr.Property_Slope=le.fit_transform(pr.Property_Slope)
pr.Neighborhood=le.fit_transform(pr.Neighborhood)
pr.Condition1=le.fit_transform(pr.Condition1)
pr.Condition2=le.fit_transform(pr.Condition2)
pr.House_Type=le.fit_transform(pr.House_Type)
pr.House_Design=le.fit_transform(pr.House_Design)

pr.Roof_Design=le.fit_transform(pr.Roof_Design)
pr.Roof_Quality=le.fit_transform(pr.Roof_Quality)
pr.Exterior1st=le.fit_transform(pr.Exterior1st)
pr.Exterior2nd=le.fit_transform(pr.Exterior2nd)
pr.Brick_Veneer_Type=le.fit_transform(pr.Brick_Veneer_Type)
pr.Exterior_Material=le.fit_transform(pr.Exterior_Material)
pr.Exterior_Condition=le.fit_transform(pr.Exterior_Condition)
pr.Foundation_Type=le.fit_transform(pr.Foundation_Type)
pr.Basement_Height=le.fit_transform(pr.Basement_Height)
pr.Basement_Condition=le.fit_transform(pr.Basement_Condition)
pr.Exposure_Level=le.fit_transform(pr.Exposure_Level)
pr.BsmtFinType1=le.fit_transform(pr.BsmtFinType1)
pr.BsmtFinType2=le.fit_transform(pr.BsmtFinType2)

pr.Heating_Type=le.fit_transform(pr.Heating_Type)
pr.Heating_Quality=le.fit_transform(pr.Heating_Quality)
pr.Air_Conditioning=le.fit_transform(pr.Air_Conditioning)
pr.Electrical_System=le.fit_transform(pr.Electrical_System)
pr.Kitchen_Quality=le.fit_transform(pr.Kitchen_Quality)
pr.Functional_Rate=le.fit_transform(pr.Functional_Rate)
pr.Fireplace_Quality=le.fit_transform(pr.Fireplace_Quality)
pr.Garage=le.fit_transform(pr.Garage)
pr.Garage_Built_Year=le.fit_transform(pr.Garage_Built_Year)
pr.Garage_Finish_Year=le.fit_transform(pr.Garage_Finish_Year)
pr.Garage_Quality=le.fit_transform(pr.Garage_Quality)
pr.Garage_Condition=le.fit_transform(pr.Garage_Condition)
pr.Pavedd_Drive=le.fit_transform(pr.Pavedd_Drive)
pr.Sale_Type=le.fit_transform(pr.Sale_Type)
pr.Sale_Condition=le.fit_transform(pr.Sale_Condition)
